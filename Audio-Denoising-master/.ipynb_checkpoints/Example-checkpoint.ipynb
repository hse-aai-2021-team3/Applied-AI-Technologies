# %%
from denoise import AudioDeNoise
from IPython.display import Audio, display

# %%
Original_file = "/Users/kevinehling/Documents/AAI/wav/test_2.wav"
Denoised_file = "/Users/kevinehling/Documents/AAI/wav/denoised.wav"

# %%
audioDenoiser = AudioDeNoise(inputFile=Original_file)
audioDenoiser.deNoise(outputFile=Denoised_file)
# Out:
# 10it [00:00, 195.69it/s]

# %%
display(Audio(Original_file))
display(Audio(Denoised_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
